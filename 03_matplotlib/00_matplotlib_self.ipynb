# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cbook, cm
from matplotlib.colors import LightSource

# Load and format data
dem = cbook.get_sample_data('jacksboro_fault_dem.npz')
z = dem['elevation']
nrows, ncols = z.shape
x = np.linspace(dem['xmin'], dem['xmax'], ncols)
y = np.linspace(dem['ymin'], dem['ymax'], nrows)
x, y = np.meshgrid(x, y)

region = np.s_[5:50, 5:50]
x, y, z = x[region], y[region], z[region]

# Set up plot
fig, ax = plt.subplots(subplot_kw=dict(projection='3d'))

ls = LightSource(270, 45)
# To use a custom hillshading mode, override the built-in shading and pass
# in the rgb colors of the shaded surface calculated from "shade".
rgb = ls.shade(z, cmap=cm.gist_earth, vert_exag=0.1, blend_mode='soft')
surf = ax.plot_surface(x, y, z, rstride=1, cstride=1, facecolors=rgb,
                       linewidth=0, antialiased=False, shade=False)

# %%
# 데이터
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# 그래프 생성
plt.plot(x, y)
plt.title("Line Graph")  # 제목
plt.xlabel("X-axis")     # X축 레이블
plt.ylabel("Y-axis")     # Y축 레이블
print(fig)
print(ax)
plt.show()
# Out:
# Figure(640x480)
# Axes3D(0.22375,0.11;0.5775x0.77)

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30])
plt.title("Line Graph")
print(fig)
print(ax)
plt.show()
# Out:
# Figure(640x480)
# Axes3D(0.22375,0.11;0.5775x0.77)

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\playdata\anaconda3\envs\pystudy_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터셋 로드
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# - 문제 1: 생존자와 사망자 수 시각화
#     - Titanic 데이터셋의 `survived` 열을 사용하여 생존자와 사망자의 수를 막대 그래프로 시각화하세요.
#     - 그래프에 제목, 축 레이블을 추가하고 색상을 설정하세요.
# - 문제 2: 성별에 따른 생존율 비교
#     - Titanic 데이터셋의 `sex`와 `survived` 열을 사용하여 성별에 따른 생존율을 막대 그래프로 시각화하세요.
#     - 성별 생존율을 비교하고 제목, 축 레이블을 추가하세요.
# - 문제 3: 클래스와 성별에 따른 생존율 비교
#     - Titanic 데이터셋의 `class`, `sex`, `survived` 열을 사용하여 그룹별 생존율을 시각화하세요.
#     - `class`를 x축으로 설정하고, 성별에 따라 색상을 구분하여 그래프를 생성하세요.
#     - 그래프에 제목, 축 레이블, 범례를 추가하세요.
# - 문제 4: 나이 분포 분석
#     - Titanic 데이터셋의 `age` 열을 사용하여 승객들의 나이 분포를 히스토그램과 KDE 그래프로 시각화하세요.
#     - 데이터에서 결측치를 제거하고 그래프를 그리세요.
#     - 히스토그램의 막대 개수(`bins`)를 적절히 설정하고 제목, 축 레이블을 추가하세요.
# - 문제 5: 나이와 요금의 관계 분석
#     - Titanic 데이터셋의 `age`, `fare`, `survived` 열을 사용하여 나이와 요금 간의 관계를 산점도로 시각화하세요.
#     - 생존 여부(`survived`)에 따라 색상을 다르게 설정하세요.
#     - 그래프에 제목, 축 레이블을 추가하세요.

# %%
- 문제 1: 생존자와 사망자 수 시각화
    - Titanic 데이터셋의 `survived` 열을 사용하여 생존자와 사망자의 수를 막대 그래프로 시각화하세요.
    - 그래프에 제목, 축 레이블을 추가하고 색상을 설정하세요.

# %%
# 생존자와 사망자 수 시각화
plt.figure(figsize=(10, 6))
sns.countplot(x='survived', data=titanic, palette='muted')
plt.title('Number of Survivors and Non-Survivors')
plt.xlabel('Survived (1=Yes, 0=No)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_34368\2780011268.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='survived', data=titanic, palette='muted')

# %%
- 문제 2: 성별에 따른 생존율 비교
    - Titanic 데이터셋의 `sex`와 `survived` 열을 사용하여 성별에 따른 생존율을 막대 그래프로 시각화하세요.
    - 성별 생존율을 비교하고 제목, 축 레이블을 추가하세요.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='survived', data=titanic, palette='dark')
plt.title('Survival Rate by Gender')
plt.xlabel('Gender (Man, Woman)')
plt.ylabel('Survival Rate')
plt.show()
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_34368\1785575122.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex', y='survived', data=titanic, palette='dark')

# %%
- 문제 3: 클래스와 성별에 따른 생존율 비교
    - Titanic 데이터셋의 `class`, `sex`, `survived` 열을 사용하여 그룹별 생존율을 시각화하세요.
    - `class`를 x축으로 설정하고, 성별에 따라 색상을 구분하여 그래프를 생성하세요.
    - 그래프에 제목, 축 레이블, 범례를 추가하세요.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 클래스와 성별에 따른 생존율 비교
titanic[['sex', 'class', 'survived']]
# Out:
#         sex   class  survived
# 0      male   Third         0
# 1    female   First         1
# 2    female   Third         1
# 3    female   First         1
# 4      male   Third         0
# ..      ...     ...       ...
# 886    male  Second         0
# 887  female   First         1
# 888  female   Third         0
# 889    male   First         1
# 890    male   Third         0
#
# [891 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
# plt.gca()
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=titanic, kind="bar",
    x="class", y="survived", hue="sex",
    palette="dark", alpha=0.8, height=6, aspect=1.0
)

g.despine(left=True)
g.set_axis_labels("Class", "Survival Rate")
g.legend.set_title("")
plt.title("Survival Rate by Class and Sex")
plt.show()

# %%
# 클래스와 성별에 따른 생존율
plt.figure(figsize=(10, 6))
sns.barplot(x='class', y='survived', hue='sex', data=titanic, palette='coolwarm')
plt.title('Survival Rate by Class and Sex')
plt.xlabel('Class')
plt.ylabel('Survival Rate')
plt.show()

# %%
- 문제 4: 나이 분포 분석
    - Titanic 데이터셋의 `age` 열을 사용하여 승객들의 나이 분포를 히스토그램과 KDE 그래프로 시각화하세요.
    - 데이터에서 결측치를 제거하고 그래프를 그리세요.
    - 히스토그램의 막대 개수(`bins`)를 적절히 설정하고 제목, 축 레이블을 추가하세요.

# %%
sns.histplot(titanic['age'], kde=True, bins=100, color='red', alpha=0.25)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
- 문제 5: 나이와 요금의 관계 분석
    - Titanic 데이터셋의 `age`, `fare`, `survived` 열을 사용하여 나이와 요금 간의 관계를 산점도로 시각화하세요.
    - 생존 여부(`survived`)에 따라 색상을 다르게 설정하세요.
    - 그래프에 제목, 축 레이블을 추가하세요.

# %%
sns.scatterplot(x='age', y='fare', hue='survived', data=titanic, palette='deep')
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 기본 데이터셋 로드
tips = sns.load_dataset('tips')

# 간단한 산점도 그리기
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title('Total Bill vs Tip')
plt.show()

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")
